# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv(r'cars_eda_analysis.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0           1        Pune  2015              41000    Diesel       Manual
# 1           2     Chennai  2011              46000    Petrol       Manual
# 2           3     Chennai  2012              87000    Diesel       Manual
# 3           4  Coimbatore  2013              40670    Diesel    Automatic
# 4           6      Jaipur  2013              86999    Diesel       Manual
#
#   Owner_Type  Mileage  Engine   Power  Seats    brand   model
# 0      First    19.67  1582.0  126.20    5.0  Hyundai   Creta
# 1      First    18.20  1199.0   88.70    5.0    Honda    Jazz
# 2      First    20.77  1248.0   88.76    7.0   Maruti  Ertiga
# 3     Second    15.20  1968.0  140.80    5.0     Audi      A4
# 4      First    23.08  1461.0   63.10    5.0   Nissan   Micra

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'brand', 'model'],
#       dtype='object')

# %%
df.drop(['Location'], axis=1, inplace=True)

# %%
df
# Out:
#       Unnamed: 0  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0              1  2015              41000    Diesel       Manual      First
# 1              2  2011              46000    Petrol       Manual      First
# 2              3  2012              87000    Diesel       Manual      First
# 3              4  2013              40670    Diesel    Automatic     Second
# 4              6  2013              86999    Diesel       Manual      First
# ...          ...   ...                ...       ...          ...        ...
# 7172        7248  2011              89411    Diesel       Manual      First
# 7173        7249  2015              59000    Petrol    Automatic      First
# 7174        7250  2012              28000    Diesel       Manual      First
# 7175        7251  2013              52262    Petrol    Automatic      Third
# 7176        7252  2014              72443    Diesel    Automatic      First
#
# ...

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#       Unnamed: 0  Year  Kilometers_Driven  Mileage  Engine   Power  Seats  \
# 0              1  2015              41000    19.67  1582.0  126.20    5.0
# 1              2  2011              46000    18.20  1199.0   88.70    5.0
# 2              3  2012              87000    20.77  1248.0   88.76    7.0
# 3              4  2013              40670    15.20  1968.0  140.80    5.0
# 4              6  2013              86999    23.08  1461.0   63.10    5.0
# ...          ...   ...                ...      ...     ...     ...    ...
# 7172        7248  2011              89411    20.54  1598.0  103.60    5.0
# 7173        7249  2015              59000    17.21  1197.0  103.60    5.0
# 7174        7250  2012              28000    23.08  1461.0   63.10    5.0
# 7175        7251  2013              52262    17.20  1197.0  103.60    5.0
# 7176        7252  2014              72443    10.00  2148.0  170.00    5.0
#
#       Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  ...  \
# ...

# %%
x=df.drop(['Mileage'], axis=1)
y=df['Mileage']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
prediction=model.predict(x_test)
prediction
# Out:
# array([22.92159018, 20.60639756, 12.84279785, ..., 19.2       ,
#        18.23665095, 12.48369392])

# %%
x.head(1)
# Out:
#    Unnamed: 0  Year  Kilometers_Driven  Engine  Power  Seats  \
# 0           1  2015              41000  1582.0  126.2    5.0
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 0              True             False                   False
#
#    Transmission_Manual  ...  model_Xcent  model_Xenon  model_Xylo  model_Yeti  \
# 0                 True  ...        False        False       False       False
#
#    model_Z4  model_Zen  model_Zest  model_i10  model_i20  model_redi-GO
# 0     False      False       False      False      False          False
#
# [1 rows x 264 columns]

# %%
x.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Kilometers_Driven', 'Engine', 'Power', 'Seats',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Transmission_Automatic',
#        'Transmission_Manual',
#        ...
#        'model_Xcent', 'model_Xenon', 'model_Xylo', 'model_Yeti', 'model_Z4',
#        'model_Zen', 'model_Zest', 'model_i10', 'model_i20', 'model_redi-GO'],
#       dtype='object', length=264)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#        'Seats', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Transmission_Automatic',
#        ...
#        'model_Xcent', 'model_Xenon', 'model_Xylo', 'model_Yeti', 'model_Z4',
#        'model_Zen', 'model_Zest', 'model_i10', 'model_i20', 'model_redi-GO'],
#       dtype='object', length=265)

# %%
new_data={'Year':2015, 'Kilometers_Driven':50000, 'Fuel_Type':'Diesel', 'Transmission':'Manual', 'Owner_Type':'First', 'Engine':1197, 'Power':81.86, 'Seats':5, 'brand':'Maruti', 'model':'Swift'}

# %%
new_data=pd.DataFrame(new_data, index=[0])

# %%
new_data
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Engine  Power  \
# 0  2015              50000    Diesel       Manual      First    1197  81.86
#
#    Seats   brand  model
# 0      5  Maruti  Swift

# %%
new_data=pd.get_dummies(new_data)

# %%
new_data
# Out:
#    Year  Kilometers_Driven  Engine  Power  Seats  Fuel_Type_Diesel  \
# 0  2015              50000    1197  81.86      5              True
#
#    Transmission_Manual  Owner_Type_First  brand_Maruti  model_Swift
# 0                 True              True          True         True

# %%
for col in x_train.columns:
    if col not in new_data.columns:
        new_data[col]=0
# Out:
# C:\Users\EgrYt\AppData\Local\Temp\ipykernel_2472\2009071174.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col]=0
# C:\Users\EgrYt\AppData\Local\Temp\ipykernel_2472\2009071174.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col]=0
# ...

# %%
new_data
# Out:
#    Year  Kilometers_Driven  Engine  Power  Seats  Fuel_Type_Diesel  \
# 0  2015              50000    1197  81.86      5              True
#
#    Transmission_Manual  Owner_Type_First  brand_Maruti  model_Swift  ...  \
# 0                 True              True          True         True  ...
#
#    model_Xcent  model_Xenon  model_Xylo  model_Yeti  model_Z4  model_Zen  \
# 0            0            0           0           0         0          0
#
#    model_Zest  model_i10  model_i20  model_redi-GO
# 0           0          0          0              0
#
# [1 rows x 264 columns]

# %%
new_data=new_data[x_train.columns]

# %%
new_pred=model.predict(new_data)
new_pred
# Out:
# array([24.15814319])

# %%
import joblib

# %%
joblib.dump(model, 'carmodel.pkl')
# Out:
# ['carmodel.pkl']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mkc=DecisionTreeClassifier()
