# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
#feature scaling minmax scaler() 90% used as it gives min 0 and max 1

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scattar plot of tips and total bills before scaling 
sns.scatterplot(x='tip',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
tips_copy=tips.copy()

# %%
cols_to_scale=['tip','total_bill']
tips[cols_to_scale]=MinMaxScaler().fit_transform(tips[cols_to_scale])

# %%
#scattar plot of tips and total bills after scaling 
sns.scatterplot(x='tip',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
#in standard scaler mean is 0 and standard deviation is 1 mainly used in gaussian data

# %%
tips
# Out:
#      total_bill       tip     sex smoker   day    time  size
# 0      0.291579  0.001111  Female     No   Sun  Dinner     2
# 1      0.152283  0.073333    Male     No   Sun  Dinner     3
# 2      0.375786  0.277778    Male     No   Sun  Dinner     3
# 3      0.431713  0.256667    Male     No   Sun  Dinner     2
# 4      0.450775  0.290000  Female     No   Sun  Dinner     4
# ..          ...       ...     ...    ...   ...     ...   ...
# 239    0.543779  0.546667    Male     No   Sat  Dinner     3
# 240    0.505027  0.111111  Female    Yes   Sat  Dinner     2
# 241    0.410557  0.111111    Male    Yes   Sat  Dinner     2
# 242    0.308965  0.083333    Male     No   Sat  Dinner     2
# 243    0.329074  0.222222  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
#label encoding for strings 
cols_to_encode=['sex','smoker','day','time']
tips[cols_to_encode]=tips[cols_to_encode].apply(LabelEncoder().fit_transform)

# %%
tips
# Out:
#      total_bill       tip  sex  smoker  day  time  size
# 0      0.291579  0.001111    0       0    2     0   0.2
# 1      0.152283  0.073333    1       0    2     0   0.4
# 2      0.375786  0.277778    1       0    2     0   0.4
# 3      0.431713  0.256667    1       0    2     0   0.2
# 4      0.450775  0.290000    0       0    2     0   0.6
# ..          ...       ...  ...     ...  ...   ...   ...
# 239    0.543779  0.546667    1       0    1     0   0.4
# 240    0.505027  0.111111    0       1    1     0   0.2
# 241    0.410557  0.111111    1       1    1     0   0.2
# 242    0.308965  0.083333    1       0    1     0   0.2
# 243    0.329074  0.222222    0       0    3     0   0.2
#
# [244 rows x 7 columns]

# %%
cols_to_scale=['sex','smoker','day','time','size']
tips[cols_to_scale]=MinMaxScaler().fit_transform(tips[cols_to_scale])

# %%
tips
# Out:
#      total_bill       tip  sex  smoker       day  time  size
# 0      0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1      0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2      0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3      0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4      0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# ..          ...       ...  ...     ...       ...   ...   ...
# 239    0.543779  0.546667  1.0     0.0  0.333333   0.0   0.4
# 240    0.505027  0.111111  0.0     1.0  0.333333   0.0   0.2
# 241    0.410557  0.111111  1.0     1.0  0.333333   0.0   0.2
# 242    0.308965  0.083333  1.0     0.0  0.333333   0.0   0.2
# 243    0.329074  0.222222  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 7 columns]

# %%
#data is ready for the machine learning now

# %%
#for ml need to separate train and test 
# 80 train and 20 test is the best way used 
#scaling first and training and testing later is efficient manne r

# %%
df=pd.read_csv(r'new_cars_data_cleaned.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# location       0
# year           0
# run            0
# fuel           0
# trans          0
# owner          0
# mileage        0
# engine         0
# power         46
# seats         53
# brand          0
# model          0
# dtype: int64

# %%
drop_row = df.copy()
drop_col = df.copy()

# %%
drop_row.dropna(axis =1)
# Out:
#       Unnamed: 0    location  year    run    fuel      trans   owner  mileage  \
# 0              0      Mumbai  2010  72000     CNG     Manual   First    26.60
# 1              1        Pune  2015  41000  Diesel     Manual   First    19.67
# 2              2     Chennai  2011  46000  Petrol     Manual   First    18.20
# 3              3     Chennai  2012  87000  Diesel     Manual   First    20.77
# 4              4  Coimbatore  2013  40670  Diesel  Automatic  Second    15.20
# ...          ...         ...   ...    ...     ...        ...     ...      ...
# 7248        7248   Hyderabad  2011  89411  Diesel     Manual   First    20.54
# 7249        7249      Mumbai  2015  59000  Petrol  Automatic   First    17.21
# 7250        7250     Kolkata  2012  28000  Diesel     Manual   First    23.08
# 7251        7251        Pune  2013  52262  Petrol  Automatic   Third    17.20
# 7252        7252       Kochi  2014  72443  Diesel  Automatic   First    10.00
#
# ...

# %%
drop_row2 = df.copy()

# %%
drop_row2.dropna()
# Out:
#       Unnamed: 0    location  year    run    fuel      trans   owner  mileage  \
# 0              0      Mumbai  2010  72000     CNG     Manual   First    26.60
# 1              1        Pune  2015  41000  Diesel     Manual   First    19.67
# 2              2     Chennai  2011  46000  Petrol     Manual   First    18.20
# 3              3     Chennai  2012  87000  Diesel     Manual   First    20.77
# 4              4  Coimbatore  2013  40670  Diesel  Automatic  Second    15.20
# ...          ...         ...   ...    ...     ...        ...     ...      ...
# 7248        7248   Hyderabad  2011  89411  Diesel     Manual   First    20.54
# 7249        7249      Mumbai  2015  59000  Petrol  Automatic   First    17.21
# 7250        7250     Kolkata  2012  28000  Diesel     Manual   First    23.08
# 7251        7251        Pune  2013  52262  Petrol  Automatic   Third    17.20
# 7252        7252       Kochi  2014  72443  Diesel  Automatic   First    10.00
#
# ...

# %%
demo=pd.read_csv(r'used_cars_data.csv')

# %%
demo
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
demo['Mileage']=demo['Mileage'].str.replace('km/kg','')

# %%
demo['Mileage']=demo['Mileage'].astype(float)

# %%
# power columns 
demo['Power']=demo['Power'].str.replace('bhp','')

# %%
demo['Power']=demo['Power'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 demo['Power']=demo['Power'].astype(float)
#
# File e:\pandas-class\venv\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File e:\pandas-class\venv\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
demo[demo['Power']=='null ']
# Out:
#       S.No.                                     Name    Location  Year  \
# 76       76                 Ford Fiesta 1.4 SXi TDCi      Jaipur  2008
# 79       79                   Hyundai Santro Xing XL   Hyderabad  2005
# 89       89                   Hyundai Santro Xing XO   Hyderabad  2007
# 120     120     Hyundai Santro Xing XL eRLX Euro III      Mumbai  2005
# 143     143      Hyundai Santro Xing XO eRLX Euro II       Kochi  2008
# ...     ...                                      ...         ...   ...
# 6891   6891                          Toyota Etios GD     Kolkata  2013
# 6896   6896                     Toyota Etios Liva GD   Hyderabad  2013
# 6947   6947                      Toyota Etios Liva G       Delhi  2012
# 7092   7092  Hyundai Santro Xing XG AT eRLX Euro III  Coimbatore  2007
# 7145   7145                      Toyota Etios Liva G     Kolkata  2012
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage   Engine  \
# ...

# %%
# ...........assignment.......
#encode used_cars_data
#scale_used_cars_data
# replace price ' ' with searched value
# same for new price' '

# %%
#fillna()
"""meana
forward fill and backward fill"""
# Out:
# 'meana\nforward fill and backward fill'
