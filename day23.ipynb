# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=pd.read_csv('tips_ready.csv')

# %%
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
tips.head()
# Out:
#    Unnamed: 0  total_bill       tip  sex  smoker       day  time  size
# 0           0    0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1           1    0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2           2    0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3           3    0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4           4    0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6

# %%
#labelled data : both input and output are given
#unlabelled data : only input is given
tips.drop('Unnamed: 0',axis=1,inplace=True)

# %%
x=tips.drop('tip',axis=1)

# %%
y=tips['tip']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
#split train and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#create an instance of lineear regression model
model=LinearRegression()

# %%
#train the model
model.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_prediction=model.predict(x_test)

# %%
new_data=pd.DataFrame({'Unnamed: 0':[243],'total_bill':[50],'sex':[2],'smoker':[3],'day':[4],'time':[5],'size':[2]})

# %%
new_predict=model.predict(new_data)
new_predict
# Out:
# array([25.69214548])

# %%
df=sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df1=pd.DataFrame(df.groupby('year')['passengers'].sum())
df1.reset_index(inplace=True)

# %%
df1
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
#predict the passengers for the yearwise

# %%
x=df1['year']
y=df1['passengers']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 model.fit(x_test,y_test)
#
# File e:\Ml-evolve\venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File e:\Ml-evolve\venv\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
#     612     accept_sparse=accept_sparse,
# ...

# %%
# this is the assignments

# %%
#...........new work...............

# %%
#one hot encoder 
#lable encoder 
#one hotr encoder is used for the categorical data for that we use get dummies

# %%
tips=pd.get_dummies(tips)

# %%
tips
# Out:
#      Unnamed: 0  total_bill       tip  sex  smoker       day  time  size
# 0             0    0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1             1    0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2             2    0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3             3    0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4             4    0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# ..          ...         ...       ...  ...     ...       ...   ...   ...
# 239         239    0.543779  0.546667  1.0     0.0  0.333333   0.0   0.4
# 240         240    0.505027  0.111111  0.0     1.0  0.333333   0.0   0.2
# 241         241    0.410557  0.111111  1.0     1.0  0.333333   0.0   0.2
# 242         242    0.308965  0.083333  1.0     0.0  0.333333   0.0   0.2
# 243         243    0.329074  0.222222  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 8 columns]

# %%
#separate x and y
x=tip1.drop('tip',axis=1)
y=tip1['tip']

# %%
x
# Out:
#      Unnamed: 0  total_bill  sex  smoker       day  time  size
# 0             0    0.291579  0.0     0.0  0.666667   0.0   0.2
# 1             1    0.152283  1.0     0.0  0.666667   0.0   0.4
# 2             2    0.375786  1.0     0.0  0.666667   0.0   0.4
# 3             3    0.431713  1.0     0.0  0.666667   0.0   0.2
# 4             4    0.450775  0.0     0.0  0.666667   0.0   0.6
# ..          ...         ...  ...     ...       ...   ...   ...
# 239         239    0.543779  1.0     0.0  0.333333   0.0   0.4
# 240         240    0.505027  0.0     1.0  0.333333   0.0   0.2
# 241         241    0.410557  1.0     1.0  0.333333   0.0   0.2
# 242         242    0.308965  1.0     0.0  0.333333   0.0   0.2
# 243         243    0.329074  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 7 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model_cat_test=LinearRegression()

# %%
model_cat_test.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred=model_cat_test.predict(x_test)

# %%
y_pred
# Out:
# array([ 2.02496192e-01,  1.06152204e-01,  2.01984656e-01,  2.55359409e-01,
#         1.51583205e-01,  1.87868829e-01,  3.06466643e-01,  1.05591452e-01,
#         1.68250733e-01,  1.96061448e-01,  1.84674759e-01, -1.47247829e-02,
#         9.02094326e-02,  1.51069261e-01,  9.76313912e-02,  1.64971034e-01,
#         2.05178174e-01,  2.37002251e-01,  1.54958965e-01,  4.07609019e-01,
#         2.32508009e-01,  2.20905581e-01,  1.90658191e-01,  8.99344252e-02,
#         2.33335447e-01,  8.69250810e-02,  1.19767239e-01,  3.28037116e-01,
#         1.12896959e-01,  4.64524910e-01,  3.62649686e-01,  4.51261544e-02,
#         1.93959770e-01,  2.69973971e-01,  2.05586914e-01,  2.45093444e-01,
#         1.50203395e-01,  4.85376212e-01,  1.04123276e-01,  1.90382745e-01,
#         7.40584070e-02,  1.25521630e-01,  2.05394821e-01,  1.36217284e-01,
#         1.11895364e-01,  8.89080709e-02,  1.16960811e-01,  1.89078392e-01,
#        -3.97581050e-04])

# %%
new_data=pd.DataFrame({'Unnamed: 0':[24],'total_bill':[5],'sex':[2],'smoker':[3],'day':[4],'time':[5],'size':[2]})

# %%
pred=model_cat_test.predict(new_data)
pred
# Out:
# array([3.00032648])
