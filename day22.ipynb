# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r'seatplanning2079.xlsx')

# %%
df.head(10)
# Out:
#    Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0           1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1           2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2           3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3           4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4           5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# 5           6    803210020006  2080    2102  Grade-11 (General)     ABIJAL
# 6           7    803210020007  2080    2102  Grade-11 (General)      ALINA
# 7           8    803210020008  2080    2102  Grade-11 (General)      ALINA
# 8           9    803210020009  2080    2102  Grade-11 (General)     ALISHA
# 9          10    803210020010  2080    2102  Grade-11 (General)     AMBIKA
#
#   Middle Name Last Name  Gender                  DOB           Father's Name  \
# ...

# %%
# combining first name last name and middle name to get full name
df['Full Name'] = df['First Name'] + ' ' + df['Middle Name'] + ' ' + df['Last Name']

# %%
df.head(10)
# Out:
#    Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0           1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1           2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2           3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3           4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4           5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# 5           6    803210020006  2080    2102  Grade-11 (General)     ABIJAL
# 6           7    803210020007  2080    2102  Grade-11 (General)      ALINA
# 7           8    803210020008  2080    2102  Grade-11 (General)      ALINA
# 8           9    803210020009  2080    2102  Grade-11 (General)     ALISHA
# 9          10    803210020010  2080    2102  Grade-11 (General)     AMBIKA
#
#   Middle Name Last Name  Gender                  DOB           Father's Name  \
# ...

# %%
df['Middle Name'].fillna(' ', inplace=True)
# Out:
# C:\Users\EgrYt\AppData\Local\Temp\ipykernel_5304\310911765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Middle Name'].fillna(' ', inplace=True)

# %%
df['Full Name'] = df['First Name'] + ' ' + df['Middle Name'] + ' ' + df['Last Name']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Registration No', 'Year', 'School', 'Program',
#        'First Name', 'Middle Name', 'Last Name', 'Gender', 'DOB',
#        'Father's Name', 'Mother's Name', 'ExamRollNo', 'Registered Subject',
#        'Full Name', 'SUb1', 'SUb2', 'SUb3', 'SUb4', 'SUb5', 'SUb6'],
#       dtype='object')

# %%
#separatiing registered subject in sub 1 ,sub2 and so on 
for i in range (0,6):
    df[f'SUb{i+1}']=df['Registered Subject'].str.split(';').str[i]

# %%
#convert all sub(1-6 ) to string
for i in range (0,6):
    df[f'SUb{i+1}']=df[f'SUb{i+1}'].astype(str)

# %%
df.head(10)
# Out:
#    Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0           1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1           2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2           3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3           4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4           5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# 5           6    803210020006  2080    2102  Grade-11 (General)     ABIJAL
# 6           7    803210020007  2080    2102  Grade-11 (General)      ALINA
# 7           8    803210020008  2080    2102  Grade-11 (General)      ALINA
# 8           9    803210020009  2080    2102  Grade-11 (General)     ALISHA
# 9          10    803210020010  2080    2102  Grade-11 (General)     AMBIKA
#
#   Middle Name Last Name  Gender                  DOB  ...  \
# 0                NEPALI    MALE  2064-03-19 00:00:00  ...
# ...

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
for i in range (0,6):
    df[f'SUb{i+1}']=df[f'SUb{i+1}'].astype(str)

# %%
df["SUb1"].describe
# Out:
# <bound method NDFrame.describe of 0       0051
# 1       0051
# 2       0051
# 3       0051
# 4       0071
#        ...
# 264     0051
# 265     0071
# 266     0051
# 267     0051
# 268     0051
# Name: SUb1, Length: 269, dtype: object>

# %%
# size_mapping={"small":1,"medium":2,"large":3}
# df["new encode"]=df["size"].map(size_mapping)

# %%
for i in range (0,6):
    df[f'SUb{i+1}']=df[f'SUb{i+1}'].str[0:4]

# %%
df.head()
# Out:
#    Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0           1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1           2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2           3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3           4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4           5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
#
#   Middle Name Last Name Gender                  DOB  ...  \
# 0                NEPALI   MALE  2064-03-19 00:00:00  ...
# 1                 MAJHI   MALE  2063-06-17 00:00:00  ...
# 2                SUBEDI   MALE  2062-06-06 00:00:00  ...
# 3                TAMANG   MALE  2062-04-29 00:00:00  ...
# 4                SUBEDI   MALE  2064-01-01 00:00:00  ...
#
#                 Mother's Name ExamRollNo                   Registered Subject  \
# 0                AMIKA NEPALI   12100089   0051; 1051; 2111; 3331; 0011; 0031
# ...

# %%
df['SUb1'].unique()
# Out:
# array([' 005', ' 007'], dtype=object)

# %%
subjects = {' 105' : 'Rural Development'  , ' 103' :'Accounting' , ' 115' :'Child Development and Learning' , ' 211' : 'Sociology', '303' : 'Economics',
           '301':'Chemistry' , '223': 'Population Studies' , '215': 'Business Studies' , '201': 'Biology', '219' : 'Political Science', '333': 'Optional English',
           '441': 'Mass Comunication' , '427' :'Com. ', '401' : 'Mathematics', '001':'Nepali' , '003':'English' , '005': 'Social Studies and Life Skill', '007':'Mathematics','101': 'Physics','211':'Sociology',
           '115':'Child Development and Learning', '211':'Sociology' ,'303':'Nepali','331':'Nepali','443':'Health and Physical Education'}

# %%
#remove the space from each subject code at front
for i in range(1,7):
    df[f'SUb{i}'] = df[f'SUb{i}'].str.strip()

# %%
#map the subject_dict with the subject code from sub1 to sub6
for i in range (0,6):
    df[f'SUb{i+1}']=df[f'SUb{i+1}'].map(subjects)

# %%
df.head()
# Out:
#    Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0           1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1           2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2           3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3           4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4           5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
#
#   Middle Name Last Name Gender                  DOB  ...  \
# 0                NEPALI   MALE  2064-03-19 00:00:00  ...
# 1                 MAJHI   MALE  2063-06-17 00:00:00  ...
# 2                SUBEDI   MALE  2062-06-06 00:00:00  ...
# 3                TAMANG   MALE  2062-04-29 00:00:00  ...
# 4                SUBEDI   MALE  2064-01-01 00:00:00  ...
#
#                 Mother's Name ExamRollNo                   Registered Subject  \
# 0                AMIKA NEPALI   12100089   0051; 1051; 2111; 3331; 0011; 0031
# ...

# %%
subjects = {'105' : 'Rural Development'  , '103' :'Accounting' , '115' :'Child Development and Learning' , '211' : 'Sociology', '303' : 'Economics',
           '301':'Chemistry' , '223': 'Population Studies' , '215': 'Business Studies' , '201': 'Biology', '219' : 'Political Science', '333': 'Optional English',
           '441': 'Mass Comunication' , '427' :'Com. ', '401' : 'Mathematics', '001':'Nepali' , '003':'English' , '005': 'Social Studies and Life Skill', '007':'Mathematics','101': 'Physics','211':'Sociology',
           '115':'Child Development and Learning', '211':'Sociology' ,'303':'Nepali','331':'Nepali','443':'Health and Physical Education'}

# %%
dataas=pd.read_csv('Diwali Sales Data.xls',encoding='iso-8859-1')

# %%
#time series analysis includes the following
#1. Trend
#2. Seasonality
#3. Cyclical
