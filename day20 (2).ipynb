# %%
import openpyxl
import pandas as pd
import numpy as np

# %% [raw]
# Types of supervised machine learning
# a)Regression
# b)Classification
# Steps for machine learning:
# -problem identification
# -data collection
#     -manually
#     - web scraping or downloading
#     -buy
# -Data preprocessing
#     -Data cleaning: handling missing values, type conversion, hyperparameter(), model parameter()
# -Encoding(label encoding, one hot encoding)
# -scaling(MinMaxScaler)
# -splitting(80%20%)
# -train model
# -error calculation(mes<, r2>)
# -deployment(heroku, aws)
#     -streamlit(), flask()

# %%
df=pd.read_csv(r"used_cars_data.csv")

# %% [raw]
# isna(), isnull(), notna(), notnull()

# %%
df_row=df.copy()
df_row1=df.copy()
df_col=df.copy()
df_col1=df.copy()

# %%
df1=df.copy()
df2=df.copy()
df2=df.copy()

# %%
df1.dropna(axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
df2.dropna(how='all')
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7253 rows x 14 columns]

# %%
remove=['Mileage','Engine','Power','Seats']

# %%
df2.dropna(subset=remove, inplace=True)
df2
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7198 rows x 14 columns]

# %%
df2.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            6193
# Price                1223
# dtype: int64

# %%
df2
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7198 rows x 14 columns]

# %%
del_col=['S.No.', 'Location', 'Owner_Type', 'New_Price','Price']

# %%
df2.drop(del_col,axis=1, inplace=True)

# %%
names=df2['Name'].str.split('',expand=True)

# %%
df2['brand']=names[0]
df2['model']=names[1]

# %%
df2.drop(['Name'],axis=1,inplace=True)

# %%
df2
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission     Mileage   Engine  \
# 0     2010              72000       CNG       Manual  26.6 km/kg   998 CC
# 1     2015              41000    Diesel       Manual  19.67 kmpl  1582 CC
# 2     2011              46000    Petrol       Manual   18.2 kmpl  1199 CC
# 3     2012              87000    Diesel       Manual  20.77 kmpl  1248 CC
# 4     2013              40670    Diesel    Automatic   15.2 kmpl  1968 CC
# ...    ...                ...       ...          ...         ...      ...
# 7248  2011              89411    Diesel       Manual  20.54 kmpl  1598 CC
# 7249  2015              59000    Petrol    Automatic  17.21 kmpl  1197 CC
# 7250  2012              28000    Diesel       Manual  23.08 kmpl  1461 CC
# 7251  2013              52262    Petrol    Automatic   17.2 kmpl  1197 CC
# 7252  2014              72443    Diesel    Automatic   10.0 kmpl  2148 CC
#
#           Power  Seats brand model
# 0     58.16 bhp    5.0           M
# 1     126.2 bhp    5.0           H
# 2      88.7 bhp    5.0           H
# 3     88.76 bhp    7.0           M
# 4     140.8 bhp    5.0           A
# ...         ...    ...   ...   ...
# 7248  103.6 bhp    5.0           V
# 7249  103.6 bhp    5.0           V
# 7250   63.1 bhp    5.0           N
# 7251  103.6 bhp    5.0           V
# 7252    170 bhp    5.0           M
#
# [7198 rows x 10 columns]

# %%
df2['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel    3838
# Petrol    3286
# CNG         62
# LPG         12
# Name: count, dtype: int64

# %%
#drop the rows where fuel type is cng or lpg 
df2=df2[df2['Fuel_Type']!='CNG']
df2=df2[df2['Fuel_Type']!='LPG']

# %%
df2['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel    3838
# Petrol    3286
# Name: count, dtype: int64

# %%
df2
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission     Mileage   Engine  \
# 1     2015              41000    Diesel       Manual  19.67 kmpl  1582 CC
# 2     2011              46000    Petrol       Manual   18.2 kmpl  1199 CC
# 3     2012              87000    Diesel       Manual  20.77 kmpl  1248 CC
# 4     2013              40670    Diesel    Automatic   15.2 kmpl  1968 CC
# 6     2013              86999    Diesel       Manual  23.08 kmpl  1461 CC
# ...    ...                ...       ...          ...         ...      ...
# 7248  2011              89411    Diesel       Manual  20.54 kmpl  1598 CC
# 7249  2015              59000    Petrol    Automatic  17.21 kmpl  1197 CC
# 7250  2012              28000    Diesel       Manual  23.08 kmpl  1461 CC
# 7251  2013              52262    Petrol    Automatic   17.2 kmpl  1197 CC
# 7252  2014              72443    Diesel    Automatic   10.0 kmpl  2148 CC
#
#           Power  Seats brand model
# 1     126.2 bhp    5.0           H
# 2      88.7 bhp    5.0           H
# 3     88.76 bhp    7.0           M
# 4     140.8 bhp    5.0           A
# 6      63.1 bhp    5.0           N
# ...         ...    ...   ...   ...
# 7248  103.6 bhp    5.0           V
# 7249  103.6 bhp    5.0           V
# 7250   63.1 bhp    5.0           N
# 7251  103.6 bhp    5.0           V
# 7252    170 bhp    5.0           M
#
# [7124 rows x 10 columns]

# %%
df2.columns
# Out:
# Index(['Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Mileage',
#        'Engine', 'Power', 'Seats', 'brand', 'model'],
#       dtype='object')

# %%
df2['Engine'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7124 entries, 1 to 7252
# Series name: Engine
# Non-Null Count  Dtype
# --------------  -----
# 7124 non-null   object
# dtypes: object(1)
# memory usage: 111.3+ KB

# %%
df2['Engine']=df2['Engine'].str.replace(' CC','')

# %%
df2['Engine']=df2['Engine'].astype(float)

# %%
df2['Power']=df2['Power'].str.replace('bhp','')

# %%
df2['Power'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7124 entries, 1 to 7252
# Series name: Power
# Non-Null Count  Dtype
# --------------  -----
# 7124 non-null   object
# dtypes: object(1)
# memory usage: 111.3+ KB

# %%
df2['Power']=df2['Power'].str.strip()

# %%
df2=df2[df2['Power']!='null']

# %%
df2["Power"]
# Out:
# 1       126.2
# 2        88.7
# 3       88.76
# 4       140.8
# 6        63.1
#         ...
# 7248    103.6
# 7249    103.6
# 7250     63.1
# 7251    103.6
# 7252      170
# Name: Power, Length: 7000, dtype: object

# %%
df2['Power']=df2['Power'].astype(float)

# %%
df2['Power'].dtype
# Out:
# dtype('float64')

# %%
df2.shape
# Out:
# (7000, 10)

# %%
df2['Power'].isnull().sum()
# Out:
# np.int64(0)

# %%
#encode string data and clean other data to be trainable
